# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.flipkart.com/realme-narzo-30-pro-5g-blade-silver-128-gb/p/itm8cb3552276c44?pid=MOBGYFAXA3RQHPXJ&lid=LSTMOBGYFAXA3RQHPXJGM2YW9&marketplace=FLIPKART&store=tyy%2F4io&srno=b_1_1&otracker=clp_metro_expandable_3_3.metroExpandable.METRO_EXPANDABLE_Shop%2BNow_mobile-phones-store_YELWEWN3DMAC_wp3&fm=neo%2Fmerchandising&iid=fd8bf93b-46d3-44c3-a9fb-fad19b334b64.MOBGYFAXA3RQHPXJ.SEARCH&ppt=clp&ppn=mobile-phones-store&ssid=x51cm7f9tc0000001643020489893'

# %%
req= requests.get(url)

# %%
content = BeautifulSoup(req.content, 'html.parser')

# %%
print(content)
# Out:
# <!DOCTYPE html>
# ...

# %%
data = content.find_all('div',{'class': '_3LWZlK'})

# %%
print(data)
# Out:
# [<div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1D-8OL">4.6<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK">3.8<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">3<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1rdVr6 _1BLPMq">1<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<
# ...

# %%
link = []
phone_names = []
start_link= 'http://www.flipkart.com'

# %%
import csv
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
